# %% [markdown]
# ### Inspect Prepared Input
#
# We use this notebook to check if the input is prepared correctly
# for the classifier.
#
# The input preparation should match the [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist).

# %%
EXAMPLE_INPUT_PATH = "example-input.npy"

# %%
import numpy as np

arr = np.load(EXAMPLE_INPUT_PATH)
arr.shape
# Out:
# (28, 28)

# %%
import matplotlib.pyplot as plt

plt.imshow(arr, cmap="gray")
